# %%
import numpy as np
import pandas as pd

# %%
country = pd.read_csv('country_forLearning.csv')
country
# Out:
#             Country                               Region  Population  \
# 0       Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1           Albania  EASTERN EUROPE                          3581655
# 2           Algeria  NORTHERN AFRICA                        32930091
# 3    American Samoa  OCEANIA                                   57794
# 4           Andorra  WESTERN EUROPE                            71201
# ..              ...                                  ...         ...
# 222       West Bank  NEAR EAST                               2460492
# 223  Western Sahara  NORTHERN AFRICA                          273008
# 224           Yemen  NEAR EAST                              21456188
# 225          Zambia  SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
print(f'data_shape = {country.shape}')
print(f'data_columns = {country.columns}')
# Out:
# data_shape = (227, 20)
# data_columns = Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
country[['Country', 'Region']].head(10)
# Out:
#              Country                               Region
# 0        Afghanistan        ASIA (EX. NEAR EAST)
# 1            Albania  EASTERN EUROPE
# 2            Algeria  NORTHERN AFRICA
# 3     American Samoa  OCEANIA
# 4            Andorra  WESTERN EUROPE
# 5             Angola  SUB-SAHARAN AFRICA
# 6           Anguilla              LATIN AMER. & CARIB
# 7  Antigua & Barbuda              LATIN AMER. & CARIB
# 8          Argentina              LATIN AMER. & CARIB
# 9            Armenia                 C.W. OF IND. STATES

# %% [markdown]
# #### ***取出某行的資料***

# %%
country.iloc[10]
# Out:
# Country                                                 Aruba
# Region                                LATIN AMER. & CARIB
# Population                                              71891
# Area (sq. mi.)                                            193
# Pop. Density (per sq. mi.)                              372,5
# Coastline (coast/area ratio)                            35,49
# Net migration                                               0
# Infant mortality (per 1000 births)                       5,89
# GDP ($ per capita)                                    28000.0
# Literacy (%)                                             97,0
# Phones (per 1000)                                       516,1
# Arable (%)                                              10,53
# Crops (%)                                                   0
# Other (%)                                               89,47
# Climate                                                     2
# ...

# %%
country.iloc[[1,3], [5,3]]
# Out:
#   Coastline (coast/area ratio)  Area (sq. mi.)
# 1                         1,26           28748
# 3                        58,29             199

# %%
country['country'] = country['Country'].str.strip()
country.set_index('country', inplace=True)
country
# Out:
#                        Country                               Region  \
# country
# Afghanistan        Afghanistan        ASIA (EX. NEAR EAST)
# Albania                Albania  EASTERN EUROPE
# Algeria                Algeria  NORTHERN AFRICA
# American Samoa  American Samoa  OCEANIA
# Andorra                Andorra  WESTERN EUROPE
# ...                        ...                                  ...
# West Bank            West Bank  NEAR EAST
# Western Sahara  Western Sahara  NORTHERN AFRICA
# Yemen                    Yemen  NEAR EAST
# Zambia                  Zambia  SUB-SAHARAN AFRICA
# Zimbabwe              Zimbabwe  SUB-SAHARAN AFRICA
#
#                 Population  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# country
# Afghanistan       31056997          647500                       48,0
# Albania            3581655           28748                      124,6
# Algeria           32930091         2381740                       13,8
# ...

# %%
country.loc['Afghanistan']
# Out:
# Country                                                 Afghanistan
# Region                                ASIA (EX. NEAR EAST)
# Population                                                 31056997
# Area (sq. mi.)                                               647500
# Pop. Density (per sq. mi.)                                     48,0
# Coastline (coast/area ratio)                                   0,00
# Net migration                                                 23,06
# Infant mortality (per 1000 births)                           163,07
# GDP ($ per capita)                                            700.0
# Literacy (%)                                                   36,0
# Phones (per 1000)                                               3,2
# Arable (%)                                                    12,13
# Crops (%)                                                      0,22
# Other (%)                                                     87,65
# ...

# %%
country.loc[['Afghanistan', 'Albania']] #使用loc[]取得多筆資料
# Out:
#                  Country                               Region  Population  \
# country
# Afghanistan  Afghanistan        ASIA (EX. NEAR EAST)             31056997
# Albania          Albania  EASTERN EUROPE                          3581655
#
#              Area (sq. mi.) Pop. Density (per sq. mi.)  \
# country
# Afghanistan          647500                       48,0
# Albania               28748                      124,6
#
#             Coastline (coast/area ratio) Net migration  \
# country
# Afghanistan                         0,00         23,06
# Albania                             1,26         -4,93
#
#             Infant mortality (per 1000 births)  GDP ($ per capita)  \
# country
# Afghanistan                             163,07               700.0
# Albania                                  21,52              4500.0
#
#             Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%)  \
# country
# ...

# %%
country.loc[['Afghanistan', 'Albania'], ['Region', 'Population']] #使用loc[]取得特定欄位資料
# Out:
#                                           Region  Population
# country
# Afghanistan        ASIA (EX. NEAR EAST)             31056997
# Albania      EASTERN EUROPE                          3581655

# %%
country.loc['China':'Japan', 'Region':'Net migration'] #使用loc[]取得特定範圍資料
# Out:
#                                                    Region  Population  \
# country
# China                       ASIA (EX. NEAR EAST)           1313973713
# Colombia                          LATIN AMER. & CARIB        43593035
# Comoros               SUB-SAHARAN AFRICA                       690948
# Congo, Dem. Rep.      SUB-SAHARAN AFRICA                     62660551
# Congo, Repub. of the  SUB-SAHARAN AFRICA                      3702314
# ...                                                   ...         ...
# Isle of Man           WESTERN EUROPE                            75441
# Israel                NEAR EAST                               6352117
# Italy                 WESTERN EUROPE                         58133509
# Jamaica                           LATIN AMER. & CARIB         2758124
# Japan                       ASIA (EX. NEAR EAST)            127463611
#
#                       Area (sq. mi.) Pop. Density (per sq. mi.)  \
# country
# ...
