# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### DataFrame

# %%
data = {
    'name':['Avery', 'Kelly', 'Jimmy'],
    'age':[27, 28, 27]
}

#DataFrame 應用
panda_df = pd.DataFrame(data)
panda_df
# Out:
#     name  age
# 0  Avery   27
# 1  Kelly   28
# 2  Jimmy   27

# %%
df = pd.DataFrame(columns=['age', 'score'])
df['score'] = np.random.randint(100, size=(20)) #0-99的隨機數
df['age'] = np.random.randint(100, size=(20)) #0-24的隨機整數

df
sorted_df = df.sort_values(by='age') #依照age排序
sorted_df
# Out:
#     age  score
# 5     2     12
# 13    7     38
# 17   10     19
# 8    29     12
# 15   37     51
# 6    39     30
# 11   39     45
# 4    42      4
# 9    48     21
# 16   48     71
# 3    51     49
# 19   56     13
# 1    75     58
# 0    75     10
# 10   88     18
# 7    90     68
# 2    92     42
# 18   96     28
# 12   98     49
# 14   99     93

# %% [markdown]
# #### 畫分佈圖

# %%
df.plot(kind='scatter', x='age', y='score') #畫散佈圖
# Out:
# <Axes: xlabel='age', ylabel='score'>

# %% [markdown]
# #### 折線圖

# %%
sorted_df.plot(x = 'age', y = 'score') #畫折線圖
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# #### 讀取文件

# %%
local_df = pd.read_csv('score.csv') #讀取csv檔
local_df
# Out:
#     Unnamed: 0  age  score_01  score_02  score_03
# 0            0   12        54        16        85
# 1            1   90        44        55        53
# 2            2   28        80        17        64
# 3            3   28        76        54        25
# 4            4   18        84        43        11
# 5            5   30        51         6        60
# 6            6   35        24        48        75
# 7            7   72        23        55        14
# 8            8   87        44        88        12
# 9            9   26        97        86        19
# 10          10   60        75        87        46
# 11          11   67        42        81        17
# 12          12   90        93        17         7
# 13          13   31        45        54        37
# 14          14    6        69        99        78
# 15          15   27        38        23         3
# 16          16   93        94        63        73
# 17          17   67        11        97        51
# ...

# %%
local_df[['age', 'score_01', 'score_02', 'score_03']].plot() #畫折線圖
# Out:
# <Axes: >

# %%
local_df.info() #顯示資料型態
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     int64
#  1   age         20 non-null     int64
#  2   score_01    20 non-null     int64
#  3   score_02    20 non-null     int64
#  4   score_03    20 non-null     int64
# dtypes: int64(5)
# memory usage: 928.0 bytes

# %%
local_df.describe() #顯示統計資料
# Out:
#        Unnamed: 0       age   score_01   score_02   score_03
# count    20.00000  20.00000  20.000000  20.000000  20.000000
# mean      9.50000  47.55000  56.300000  52.750000  45.900000
# std       5.91608  30.72711  26.732791  30.487055  30.942902
# min       0.00000   4.00000  11.000000   6.000000   3.000000
# 25%       4.75000  26.75000  41.000000  21.500000  16.250000
# 50%       9.50000  33.00000  52.500000  54.500000  48.500000
# 75%      14.25000  74.00000  77.000000  82.250000  73.500000
# max      19.00000  93.00000  97.000000  99.000000  96.000000

# %%
local_df['score_01'] = np.nan
local_df
# Out:
#     Unnamed: 0  age  score_01  score_02  score_03 socere_01
# 0            0   12       NaN        16        85       xxx
# 1            1   90       NaN        55        53       xxx
# 2            2   28       NaN        17        64       xxx
# 3            3   28       NaN        54        25       xxx
# 4            4   18       NaN        43        11       xxx
# 5            5   30       NaN         6        60       xxx
# 6            6   35       NaN        48        75       xxx
# 7            7   72       NaN        55        14       xxx
# 8            8   87       NaN        88        12       xxx
# 9            9   26       NaN        86        19       xxx
# 10          10   60       NaN        87        46       xxx
# 11          11   67       NaN        81        17       xxx
# 12          12   90       NaN        17         7       xxx
# 13          13   31       NaN        54        37       xxx
# 14          14    6       NaN        99        78       xxx
# ...

# %%
local_df.fillna('xxx', inplace = True) #填補缺失值
local_df
# Out:
#     Unnamed: 0  age score_01  score_02  score_03 socere_01
# 0            0   12      xxx        16        85       xxx
# 1            1   90      xxx        55        53       xxx
# 2            2   28      xxx        17        64       xxx
# 3            3   28      xxx        54        25       xxx
# 4            4   18      xxx        43        11       xxx
# 5            5   30      xxx         6        60       xxx
# 6            6   35      xxx        48        75       xxx
# 7            7   72      xxx        55        14       xxx
# 8            8   87      xxx        88        12       xxx
# 9            9   26      xxx        86        19       xxx
# 10          10   60      xxx        87        46       xxx
# 11          11   67      xxx        81        17       xxx
# 12          12   90      xxx        17         7       xxx
# 13          13   31      xxx        54        37       xxx
# 14          14    6      xxx        99        78       xxx
# ...

# %% [markdown]
# #### 數據處理

# %%
print(local_df['score_02'].mean()) #計算平均值
print(local_df['score_02'].max()) #計算最大值
print(local_df['score_02'].min()) #計算最小值
print(local_df['score_02'].std()) #計算標準差
print(local_df['score_02'].median()) #計算中位數
# Out:
# 52.75
# 99
# 6
# 30.487055061382847
# 54.5
# 0    17
# 1    54
# 2    55
# Name: score_02, dtype: int64

# %%
df = pd.DataFrame(columns=['age', 'score_01', 'score_02', 'score_03'])
df['score_01'] = np.random.randint(100, size=(20)) #0-99的隨機數
df['score_02'] = np.random.randint(100, size=(20)) #0-99的隨機數
df['score_03'] = np.random.randint(100, size=(20)) #0-99的隨機數
df['age'] = np.random.randint(100, size=(20)) #0-24的隨機整數

df.to_csv('score.csv') #存成csv檔
